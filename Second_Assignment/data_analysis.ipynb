# %% [markdown]
# ## Data Processes: Second Assignment (first part)
#
# ### Group:
# Víctor Morcuende Castell, 47315589N
#
# Guillermo Nájera Lavid, 70845359T
#
# Javier Rocamora García, 20081979N
#
# Antonio Ruiz García, 06601574E

# %%
import matplotlib.pyplot as plt
import pandas as pd
from statsmodels.graphics.mosaicplot import mosaic

# %% [markdown]
# Importing the dataset already cleaned and pre-processed from an excel (it is the final dataset but without the One Hot Encoder algorithm applied)

# %%
df = pd.read_excel("output_def.xlsx")

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# Plotting with the different variables in order to see the distribution of the different values and looking on those variables which are of interest

# %%
df_preprocessed_def = pd.read_excel("output_def_preprocess.xlsx")

# %%
# Bar plot of sides of the tumors
arr = [[df_preprocessed_def['side_left'].astype(int).sum(),
        df_preprocessed_def['side_right'].astype(int).sum(),
        df_preprocessed_def['side_unknown'].astype(int).sum()]]

# converting the array to DF
df_aux = pd.DataFrame(arr,
                   index = ['ehr'],
                   columns = ['side_left', 'side_right', 'side_unkwnown'])

print(df_aux)
df_aux.plot.bar()
print()


# Bar plot of the grades of the tumors
arr = [[df_preprocessed_def['grade_1.0'].astype(int).sum(),
        df_preprocessed_def['grade_2.0'].astype(int).sum(),
        df_preprocessed_def['grade_3.0'].astype(int).sum()]]

# converting the array to DF
df_aux = pd.DataFrame(arr,
                   index = ['ehr'],
                   columns = ['grade_1.0', 'grade_2.0', 'grade_3.0'])

print(df_aux)
df_aux.plot.bar()
print()


# Bar plot of the hist_type of the tumors
arr = [[df_preprocessed_def['hist_type_ductal'].astype(int).sum(),
        df_preprocessed_def['hist_type_lobular'].astype(int).sum(),
        df_preprocessed_def['hist_type_unknown'].astype(int).sum()]]

# converting the array to DF
df_aux = pd.DataFrame(arr,
                   index = ['ehr'],
                   columns = ['hist_type_ductal', 'hist_type_lobular', 'hist_type_unknown'])

print(df_aux)
df_aux.plot.bar()
print()


# Bar plot of the invasive tumors
arr = [[df_preprocessed_def['invasive'].astype(int).sum(),
        (df_preprocessed_def['invasive'].shape[0] - df_preprocessed_def['invasive'].astype(int).sum())]]

# converting the array to DF
df_aux = pd.DataFrame(arr,
                   index = ['invasive'],
                   columns = ['YES', 'NO'])

print(df_aux)
df_aux.plot.bar()
print()


# Bar plot of the er_positive, pr_positive
arr = [[df_preprocessed_def['er_positive'].astype(int).sum(),
        df_preprocessed_def['pr_positive'].astype(int).sum()]]

# converting the array to DF
df_aux = pd.DataFrame(arr,
                   index = ['ehr'],
                   columns = ['er_positive', 'pr_positive'])

print(df_aux)
df_aux.plot.bar()
print()

# Scatter plot of the ki67
print(df_preprocessed_def.loc[:, ['ki67', 'ehr']])

df_preprocessed_def.loc[:, ['ki67', 'ehr']].plot(kind='scatter',    # kind of plot to show
        x='ehr',
        y='ki67',
        title='ki67 Scatter plot'
       )


# Box plot of the ki67
df_preprocessed_def.loc[:, ['ki67', 'ehr']].plot(kind='box',    # kind of plot to show
        x='ehr',
        y='ki67',
        title='ki67 Box plot'
       )


# Box plot of the menarche_age, menopause_age
print(df_preprocessed_def.loc[:, ['menopause_age', 'menarche_age', 'ehr']])

df_preprocessed_def.loc[:, ['menopause_age', 'menarche_age', 'ehr']].plot(kind='box',    # kind of plot to show
        x='ehr',
        y=['menarche_age', 'menopause_age'],
        title='menarche_age and menopause_age Box plot'
       )


# Pregnancy analysis
print(df_preprocessed_def.loc[:, ['pregnancy', 'ehr']])

df_preprocessed_def.loc[:, ['pregnancy', 'ehr']].plot(kind='box',    # kind of plot to show
        x='ehr',
        y='pregnancy',
        title='pregnancy Box plot'
       )


# Abort analysis
print(df_preprocessed_def.loc[:, ['abort', 'ehr']])

df_preprocessed_def.loc[:, ['abort', 'ehr']].plot(kind='box',    # kind of plot to show
        x='ehr',
        y='abort',
        title='abort Box plot'
       )


# Birth analysis
print(df_preprocessed_def.loc[:, ['birth', 'ehr']])

df_preprocessed_def.loc[:, ['birth', 'ehr']].plot(kind='box',    # kind of plot to show
        x='ehr',
        y='birth',
        title='birth Box plot'
       )

df_birth = pd.DataFrame(df_preprocessed_def.groupby(['birth'])['ehr'].count())
print(df_birth)

df_birth.plot(kind = 'barh',
         title = 'Birth Horizontal Bar Analysis')


# Caesarean analysis
pd.DataFrame(df_preprocessed_def.groupby(['caesarean'])['ehr'].count()).plot(kind = 'barh',
                                                                              title = 'Caesarean Horizontal Bar')

pd.DataFrame(df_preprocessed_def.groupby(['caesarean'])['ehr'].count()).plot(kind = 'box',
                                                                              title = 'Caesarean Box plot')


# age_diagnosed analysis
pd.DataFrame(df_preprocessed_def.groupby(['age_diagnosed'])['ehr'].count()).plot(kind = 'barh',
                                                                              title = 'age_diagnosed Horizontal Bar')

pd.DataFrame(df_preprocessed_def['age_diagnosed']).plot(kind = 'box',
                                                         title = 'age_diagnosed Box plot')
# Out:
#      side_left  side_right  side_unkwnown
# ehr          7           7            233
#
#      grade_1.0  grade_2.0  grade_3.0
# ehr         46        170         31
#
#      hist_type_ductal  hist_type_lobular  hist_type_unknown
# ehr               117                 20                104
#
#           YES  NO
# invasive  213  34
#
#      er_positive  pr_positive
# ehr          208          183
#
#           ki67   ehr
# 0    20.465116  6849
# 1    20.465116   268
# 2     0.000000  1458
# 3    17.000000  2013
# 4    44.000000  1350
# ..         ...   ...
# 242  20.465116    88
# 243  20.465116  5062
# 244  20.465116  3412
# 245  20.465116  2006
# 246  20.465116  7496
#
# [247 rows x 2 columns]
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:1070: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
#      menopause_age  menarche_age   ehr
# 0               51            17  6849
# 1               49            12   268
# 2               49            11  1458
# 3               49            13  2013
# 4               49            14  1350
# ..             ...           ...   ...
# 242             49            13    88
# 243             49            13  5062
# 244             49            13  3412
# 245             49            13  2006
# 246             49            13  7496
#
# [247 rows x 3 columns]
#      pregnancy   ehr
# 0            2  6849
# 1            2   268
# 2            2  1458
# 3            0  2013
# 4            3  1350
# ..         ...   ...
# 242          0    88
# 243          0  5062
# 244          0  3412
# 245          0  2006
# 246          0  7496
#
# [247 rows x 2 columns]
#      abort   ehr
# 0        0  6849
# 1        0   268
# 2        0  1458
# 3        0  2013
# 4        0  1350
# ..     ...   ...
# 242      0    88
# 243      0  5062
# 244      0  3412
# 245      0  2006
# 246      0  7496
#
# [247 rows x 2 columns]
#      birth   ehr
# 0        2  6849
# 1        2   268
# 2        2  1458
# 3        0  2013
# 4        3  1350
# ..     ...   ...
# 242      0    88
# 243      0  5062
# 244      0  3412
# 245      0  2006
# 246      0  7496
#
# [247 rows x 2 columns]
#        ehr
# birth
# 0      145
# 1       30
# 2       48
# 3       17
# 4        5
# 5        1
# 6        1
# <AxesSubplot: title={'center': 'age_diagnosed Box plot'}>

# %% [markdown]
# - n_tumor analysis

# %%
print(df_preprocessed_def.groupby(['n_tumor'])['ehr'].count())
pd.DataFrame(df_preprocessed_def.groupby(['n_tumor'])['ehr'].count()).plot(kind = 'barh', title = 'n_tumor Horizontal Bar')
pd.DataFrame(df_preprocessed_def.groupby(['n_tumor'])['ehr'].count()).plot(kind = 'box', title = 'n_tumor Box Analyplotsis')
# Out:
# n_tumor
# 1    245
# 3      2
# Name: ehr, dtype: int64
# <AxesSubplot: title={'center': 'n_tumor Box Analyplotsis'}>

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# Looking at the correlation between different variables

# %%
print(df)
# Out:
#       ehr     side  neoadjuvant  grade  invasive  er_positive  pr_positive  \
# 0    6849  unknown            0      1         1            1            1
# 1     268  unknown            0      2         1            1            1
# 2    1458  unknown            0      1         1            1            1
# 3    2013  unknown            1      3         1            1            1
# 4    1350  unknown            0      2         1            0            1
# ..    ...      ...          ...    ...       ...          ...          ...
# 242    88  unknown            0      2         1            1            1
# 243  5062  unknown            0      2         1            1            1
# 244  3412  unknown            0      2         1            1            1
# 245  2006  unknown            0      2         1            1            1
# 246  7496  unknown            0      2         1            1            1
#
#      her2_positive hist_type       ki67  ...  age_diagnosed  survival_time  \
# 0                1    ductal  20.465116  ...             49           1000
# 1                0   unknown  20.465116  ...             65           1000
# 2                0    ductal   0.000000  ...             64           1000
# 3                1    ductal  17.000000  ...             37           1000
# 4                0    ductal  44.000000  ...             52             19
# ..             ...       ...        ...  ...            ...            ...
# 242              0    ductal  20.465116  ...             47           1000
# 243              0    ductal  20.465116  ...             47           1000
# 244              0    ductal  20.465116  ...             47           1000
# 245              0    ductal  20.465116  ...             47           1000
# 246              0    ductal  20.465116  ...             47           1000
#
#      recurrence_time  n_tumor  t  n  m  t_after_neoadj  n_after_neoadj  \
# 0               1000        3  2  0  0               2               0
# 1               1000        3  2  0  0               2               0
# 2               1000        1  1  0  0               1               0
# 3               1000        1  2  1  1               1               2
# 4               1000        1  1  0  0               1               0
# ..               ...      ... .. .. ..             ...             ...
# 242             1000        1  1  1  0               1               1
# 243             1000        1  1  1  0               1               1
# 244             1000        1  0  0  0               0               0
# 245             1000        1  1  1  0               0               1
# 246             1000        1  2  1  0               2               1
#
#      m_after_neoadj
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ..              ...
# 242               0
# 243               0
# 244               0
# 245               0
# 246               0
#
# [247 rows x 26 columns]

# %%
# Labelizer contains the number of data that has both labels (it can be seen in crosstable)
def categorical_relation(var1,var2,labelizer):
  crosstable=pd.crosstab(df[var1],df[var2])
  print(crosstable)
  labelizer = labelizer
  mosaic(df,[var1,var2],gap=0.01, title='Relation between ' + var1 + ' and ' + var2,horizontal = False,labelizer = labelizer)

categorical_relation('neoadjuvant','grade',
                      lambda k:{('0','1'):44  ,('0','2'):136  ,('0','3'):18,('1','1'):2,('1','2'):34,('1','3'):13}[k])
# Out:
# grade         1    2   3
# neoadjuvant
# 0            44  136  18
# 1             2   34  13

# %%
def boxplot(categorical, numerical):
  data = []
  for type in (df[categorical]).unique():
    aux = []
    for i in range(len(df['ehr'])):
      if df[categorical][i] == type:
        aux.append(df[numerical][i])
    data.append(aux)

  plt.boxplot(data, vert = False, labels = df[categorical].unique())
  plt.title("Relation between " + numerical +" and "+ categorical)
  plt.show()

boxplot('hist_type','ki67')
boxplot('hist_type','age_diagnosed')
boxplot('hist_type','abort')

# %%
def numerical_relation(var1,var2):
  data1 = df[var1]
  data2 = df[var2]
  plt.plot(data1,data2,"bo")
  plt.xlabel(var1)
  plt.ylabel(var2)
  plt.show()

# Relation between age of diagnose and other variables
numerical_relation('menarche_age','age_diagnosed')
numerical_relation('menopause_age','age_diagnosed')
numerical_relation('pregnancy','age_diagnosed')
numerical_relation('abort','age_diagnosed')
numerical_relation('birth','age_diagnosed')
